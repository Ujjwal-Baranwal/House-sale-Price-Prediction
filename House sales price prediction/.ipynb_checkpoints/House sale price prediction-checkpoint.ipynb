# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d_train = pd.read_csv('train.csv')
d_test = pd.read_csv('test.csv')
combine = [d_train, d_test]

# %%
d_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
len(d_train)
# Out:
# 1460

# %%
d_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
for df in combine:
    df = df.loc[:, df.isnull().mean() < .6]
    print(df.shape)
# Out:
# (1460, 77)
# (1459, 76)

# %%
d_train.shape
d_test.shape
# Out:
# (1459, 80)

# %%
for df in combine:
    thresh = len(df) * .9
    df.dropna(thresh = thresh, axis = 1, inplace = True)
    print(df.shape)
# Out:
# (1460, 75)
# (1459, 74)

# %%
d_train.shape
d_test.shape
# Out:
# (1459, 74)

# %%
1423/1460
# Out:
# 0.9746575342465753

# %% [markdown]
# # Finding out best features which are highly correlated to target variable

# %%
cormat = d_train.corr()

# %%
plt.figure(figsize=(13,10))
sns.heatmap(cormat,fmt='.2g',xticklabels=cormat.columns,yticklabels=cormat.index,square = True)
plt.show()

# %%
cormat = cormat[np.array(np.abs(d_train.corr()['SalePrice'])>0.6)]

# %%
cormat.shape
# Out:
# (7, 37)

# %%
cormat.index
# Out:
# Index(['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageCars',
#        'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
#d_train.drop(cormat.index.tolist(),axis =1)
d_train = d_train[cormat.index.tolist()]
d_test = d_test[['OverallQual', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageCars','GarageArea']]

# %%
d_train
# Out:
#       OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea  \
# 0               7          856       856       1710           2         548
# 1               6         1262      1262       1262           2         460
# 2               7          920       920       1786           2         608
# 3               7          756       961       1717           3         642
# 4               8         1145      1145       2198           3         836
# ...           ...          ...       ...        ...         ...         ...
# 1455            6          953       953       1647           2         460
# 1456            6         1542      2073       2073           2         500
# 1457            7         1152      1188       2340           1         252
# 1458            5         1078      1078       1078           1         240
# 1459            5         1256      1256       1256           1         276
#
#       SalePrice
# 0        208500
# 1        181500
# ...

# %%
sns.pairplot(d_train)
plt.show()

# %%
d_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1460 non-null   int64
#  1   TotalBsmtSF  1460 non-null   int64
#  2   1stFlrSF     1460 non-null   int64
#  3   GrLivArea    1460 non-null   int64
#  4   GarageCars   1460 non-null   int64
#  5   GarageArea   1460 non-null   int64
#  6   SalePrice    1460 non-null   int64
# dtypes: int64(7)
# memory usage: 80.0 KB

# %%
d_train.describe()
# Out:
#        OverallQual  TotalBsmtSF     1stFlrSF    GrLivArea   GarageCars  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean      6.099315  1057.429452  1162.626712  1515.463699     1.767123
# std       1.382997   438.705324   386.587738   525.480383     0.747315
# min       1.000000     0.000000   334.000000   334.000000     0.000000
# 25%       5.000000   795.750000   882.000000  1129.500000     1.000000
# 50%       6.000000   991.500000  1087.000000  1464.000000     2.000000
# 75%       7.000000  1298.250000  1391.250000  1776.750000     2.000000
# max      10.000000  6110.000000  4692.000000  5642.000000     4.000000
#
#         GarageArea      SalePrice
# count  1460.000000    1460.000000
# mean    472.980137  180921.195890
# std     213.804841   79442.502883
# min       0.000000   34900.000000
# 25%     334.500000  129975.000000
# 50%     480.000000  163000.000000
# 75%     576.000000  214000.000000
# max    1418.000000  755000.000000

# %% [markdown]
# # Detecting outliers and dropping them

# %%
plt.scatter(d_train['SalePrice'],d_train['TotalBsmtSF'])
plt.show()

# %%
(d_train['TotalBsmtSF']>6000).sum()
# Out:
# 1

# %%
d_train.TotalBsmtSF.sort_values(ascending = False)[:1]
# Out:
# 1298    6110
# Name: TotalBsmtSF, dtype: int64

# %%
d_train = d_train.drop(d_train.index[[1298]])

# %%
d_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1459 entries, 0 to 1459
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1459 non-null   int64
#  1   TotalBsmtSF  1459 non-null   int64
#  2   1stFlrSF     1459 non-null   int64
#  3   GrLivArea    1459 non-null   int64
#  4   GarageCars   1459 non-null   int64
#  5   GarageArea   1459 non-null   int64
#  6   SalePrice    1459 non-null   int64
# dtypes: int64(7)
# memory usage: 91.2 KB

# %%
plt.scatter(d_train['SalePrice'],d_train['TotalBsmtSF'])
plt.show()

# %%
d_train.index[d_train['TotalBsmtSF'] == 6110]
# Out:
# Int64Index([], dtype='int64')

# %%
d_train.iloc[1297,:]
# Out:
# OverallQual         6
# TotalBsmtSF       547
# 1stFlrSF         1072
# GrLivArea        1072
# GarageCars          2
# GarageArea        525
# SalePrice      140000
# Name: 1297, dtype: int64

# %%
plt.scatter(d_train['SalePrice'],d_train['1stFlrSF'])
plt.show()

# %%
d_train.head()
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea  \
# 0            7          856       856       1710           2         548
# 1            6         1262      1262       1262           2         460
# 2            7          920       920       1786           2         608
# 3            7          756       961       1717           3         642
# 4            8         1145      1145       2198           3         836
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
plt.scatter(d_train['SalePrice'],d_train['GrLivArea'])
plt.show()
d_train[d_train.GrLivArea < 4000]
# Out:
#       OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea  \
# 0               7          856       856       1710           2         548
# 1               6         1262      1262       1262           2         460
# 2               7          920       920       1786           2         608
# 3               7          756       961       1717           3         642
# 4               8         1145      1145       2198           3         836
# ...           ...          ...       ...        ...         ...         ...
# 1455            6          953       953       1647           2         460
# 1456            6         1542      2073       2073           2         500
# 1457            7         1152      1188       2340           1         252
# 1458            5         1078      1078       1078           1         240
# 1459            5         1256      1256       1256           1         276
#
#       SalePrice
# 0        208500
# 1        181500
# ...

# %%
d_train.index[((d_train['GrLivArea']>4000) & (d_train['SalePrice']<350000)) == True]
# Out:
# Int64Index([523], dtype='int64')

# %%
d_train.iloc[523,:]
# Out:
# OverallQual        10
# TotalBsmtSF      3138
# 1stFlrSF         3138
# GrLivArea        4676
# GarageCars          3
# GarageArea        884
# SalePrice      184750
# Name: 523, dtype: int64

# %%
d_train.drop(523,inplace = True)

# %%
plt.scatter(d_train['SalePrice'],d_train['GarageArea'])
plt.show()

# %%
d_train.index[((d_train['GarageArea']>1200) & (d_train['SalePrice']<350000)) == True]
# Out:
# Int64Index([581, 1061, 1190], dtype='int64')

# %%
d_train.drop([581,1061,1190],inplace = True)

# %%
d_test
# Out:
#       OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea
# 0               5        882.0       896        896         1.0       730.0
# 1               6       1329.0      1329       1329         1.0       312.0
# 2               5        928.0       928       1629         2.0       482.0
# 3               6        926.0       926       1604         2.0       470.0
# 4               8       1280.0      1280       1280         2.0       506.0
# ...           ...          ...       ...        ...         ...         ...
# 1454            4        546.0       546       1092         0.0         0.0
# 1455            4        546.0       546       1092         1.0       286.0
# 1456            5       1224.0      1224       1224         2.0       576.0
# 1457            5        912.0       970        970         0.0         0.0
# 1458            7        996.0       996       2000         3.0       650.0
#
# [1459 rows x 6 columns]

# %%
d_train.head(10)
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea  \
# 0            7          856       856       1710           2         548
# 1            6         1262      1262       1262           2         460
# 2            7          920       920       1786           2         608
# 3            7          756       961       1717           3         642
# 4            8         1145      1145       2198           3         836
# 5            5          796       796       1362           2         480
# 6            8         1686      1694       1694           2         636
# 7            7         1107      1107       2090           2         484
# 8            7          952      1022       1774           2         468
# 9            5          991      1077       1077           1         205
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
# 5     143000
# 6     307000
# 7     200000
# 8     129900
# 9     118000

# %%
d_test.head(10)
# Out:
#    OverallQual  TotalBsmtSF  1stFlrSF  GrLivArea  GarageCars  GarageArea
# 0            5        882.0       896        896         1.0       730.0
# 1            6       1329.0      1329       1329         1.0       312.0
# 2            5        928.0       928       1629         2.0       482.0
# 3            6        926.0       926       1604         2.0       470.0
# 4            8       1280.0      1280       1280         2.0       506.0
# 5            6        763.0       763       1655         2.0       440.0
# 6            6       1168.0      1187       1187         2.0       420.0
# 7            6        789.0       789       1465         2.0       393.0
# 8            7       1300.0      1341       1341         2.0       506.0
# 9            4        882.0       882        882         2.0       525.0

# %%
X_train = d_train.drop(['SalePrice'],axis =1)
Y_train = d_train['SalePrice']
X_test = d_test.copy()
print(X_train.shape,Y_train.shape,X_test.shape)
# Out:
# (1455, 6) (1455,) (1459, 6)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, Y_train)
Y_pred = reg.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-706c750c25c7> in <module>
#       1 reg = LinearRegression().fit(X_train, Y_train)
# ----> 2 Y_pred = reg.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     216         check_is_fitted(self)
#     217
# --> 218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#
# ...

# %% [markdown]
# Nan values are there so we have to impute them

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1459 non-null   int64
#  1   TotalBsmtSF  1458 non-null   float64
#  2   1stFlrSF     1459 non-null   int64
#  3   GrLivArea    1459 non-null   int64
#  4   GarageCars   1458 non-null   float64
#  5   GarageArea   1458 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 68.5 KB

# %%
X_test.loc[X_test['GarageCars'].isna(),:].index
# Out:
# Int64Index([1116], dtype='int64')

# %%
X_test.iloc[1116,:]
# Out:
# OverallQual       5.0
# TotalBsmtSF     859.0
# 1stFlrSF        942.0
# GrLivArea      1828.0
# GarageCars        NaN
# GarageArea        NaN
# Name: 1116, dtype: float64

# %%
X_test.loc[1116,['GarageCars','GarageArea']] = 1

# %%
plt.scatter(X_test['GrLivArea'],X_test['GarageCars'])

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1459 non-null   int64
#  1   TotalBsmtSF  1458 non-null   float64
#  2   1stFlrSF     1459 non-null   int64
#  3   GrLivArea    1459 non-null   int64
#  4   GarageCars   1459 non-null   float64
#  5   GarageArea   1459 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 68.5 KB

# %%
X_test.loc[X_test['TotalBsmtSF'].isna(),'TotalBsmtSF'] = X_test['TotalBsmtSF'].mean()

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OverallQual  1459 non-null   int64
#  1   TotalBsmtSF  1459 non-null   float64
#  2   1stFlrSF     1459 non-null   int64
#  3   GrLivArea    1459 non-null   int64
#  4   GarageCars   1459 non-null   float64
#  5   GarageArea   1459 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 68.5 KB

# %%
# Model fitting
reg = LinearRegression().fit(X_train, Y_train)
Y_pred = reg.predict(X_test)

# %%
# finding accuracy score
acc = round(reg.score(X_train, Y_train) * 100, 2)
acc
# Out:
# 80.59

# %%
reg.score(X_train,Y_train)
# Out:
# 0.805870548737383

# %%
Y_pred
# Out:
# array([123866.61016031, 171275.07384898, 158269.4577608 , ...,
#        155140.9239723 ,  92980.50955405, 236624.46573002])

# %%
len(Y_pred)
# Out:
# 1459

# %%
df1 = pd.Series(np.linspace(1461,2919,num=1459))
df2 = pd.Series(Y_pred)

# %%
final = pd.concat([df1,df2],axis=1)

# %%
final.rename(columns={0:'Id',1:'SalePrice'},inplace =True)
final
# Out:
#           Id      SalePrice
# 0     1461.0  123866.610160
# 1     1462.0  171275.073849
# 2     1463.0  158269.457761
# 3     1464.0  178178.002534
# 4     1465.0  223192.417462
# ...      ...            ...
# 1454  2915.0   59812.094371
# 1455  2916.0   76954.129094
# 1456  2917.0  155140.923972
# 1457  2918.0   92980.509554
# 1458  2919.0  236624.465730
#
# [1459 rows x 2 columns]

# %%
columns=['Id','SalePrice']

# %%
isinstance(final, pd.DataFrame)
# Out:
# True

# %%
final.to_csv('my_submission.csv',index=None)

# %%
final.dtypes
# Out:
# Id           float64
# SalePrice    float64
# dtype: object

# %%
pd.to_numeric(final['Id'])
# Out:
# 0       1461.0
# 1       1462.0
# 2       1463.0
# 3       1464.0
# 4       1465.0
#          ...
# 1454    2915.0
# 1455    2916.0
# 1456    2917.0
# 1457    2918.0
# 1458    2919.0
# Name: Id, Length: 1459, dtype: float64

# %%
final.dtypes
# Out:
# Id           float64
# SalePrice    float64
# dtype: object

# %%
final['Id'] = final['Id'].astype('int32')

# %%
final
# Out:
#         Id      SalePrice
# 0     1461  123866.610160
# 1     1462  171275.073849
# 2     1463  158269.457761
# 3     1464  178178.002534
# 4     1465  223192.417462
# ...    ...            ...
# 1454  2915   59812.094371
# 1455  2916   76954.129094
# 1456  2917  155140.923972
# 1457  2918   92980.509554
# 1458  2919  236624.465730
#
# [1459 rows x 2 columns]

# %%
final.to_csv('my_submission.csv',index=None)
